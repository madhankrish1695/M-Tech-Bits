# %%
distanceToMysuruMiles =  92
print(type(distanceToMysuruMiles))
mileToKm = 1.6
print(type(mileToKm))
distanceToMysuruKm = distanceToMysuruMiles * mileToKm
print(type(distanceToMysuruKm))
print(distanceToMysuruKm)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# 147.20000000000002

# %%
x = "10" #this is string
y = "20"# this is string
x + y
# Out:
# '1020'

# %%
print(type(distanceToMysuruMiles))
# Out:
# <class 'int'>

# %%
marathonDistanceMiles = 20
marathonDistanceKm = marathonDistanceMiles * mileToKm
print(marathonDistanceKm)
# Out:
# 32.0

# %%
x = 43
y = 64

isxDivisibleBy2 = (x % 2) == 0
isyDivisibleBy3 = (y % 3) == 0

print(isxDivisibleBy2)
print(isyDivisibleBy3)
# Out:
# False
# False

# %%
aString = "Python"
anotherString = "Rocks "
aString + " " + anotherString * 3
# Out:
# 'Python Rocks Rocks Rocks '

# %%
aString.lower()
# Out:
# 'python'

# %% [markdown]
# lower()
# upper()
# strip()
# len()
# rstrip()
# lstrip()
# find()
# startwith()

# %%
someString = "Welcome"
print(someString.lower())
print(someString.upper())
print(len(someString))
print(anotherString)
print(anotherString.lstrip())
print(someString[0])
# Out:
# welcome
# WELCOME
# 7
# Rocks
# Rocks
# W

# %%
someString = "Python"
print(someString)

# %%
atuple = ("a", "b", "c", "d",1)
anotherTuple = ("a",)
print(atuple + anotherTuple)#Concatenation
print(len(anotherTuple))#length
print(atuple*3)#Repitition
# Out:
# ('a', 'b', 'c', 'd', 1, 'a')
# 1
# ('a', 'b', 'c', 'd', 1, 'a', 'b', 'c', 'd', 1, 'a', 'b', 'c', 'd', 1)

# %%
#Multiline Strings

multilineString = "This is  \\n Multiline String"
print(multilineString)

# %%
stringOne = "Python is powerful"
stringTwo = " and Versatile"
anumber = 1
print(stringOne , stringTwo , anumber)

# %%
pi =  3.14159
d = 12756
c = pi * d

#print using + and casting

print("Earth's diameter at equator " + str(d))
print("Equator's circumference" , c)
print("Equator's circumference {:.2f} {:.3f} {:.3f}".format(c,c, pi))
# Out:
# Earth's diameter at equator 12756
# Equator's circumference 40074.12204
# Equator's circumference 40074.12 40074.122 3.142
